# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Thu May 15 11:21:38 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA L4                      Off |   00000000:00:03.0 Off |                    0 |
# | N/A   64C    P8             15W /   72W |       0MiB /  23034MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 56.9 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Metadata

# %%
# !pip install -q git+https://github.com/tensorflow/docs
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for tensorflow-docs (setup.py) ... done

# %%
import pandas as pd
import json
import cv2
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import seaborn as sns
import keras
from tensorflow_docs.vis import embed

# %%
df = pd.read_csv('/content/drive/MyDrive/Dataset/metadata.csv')

# %% [markdown]
# ## Class names and label map

# %%
class_names = []
class_idx = {}

with open('/content/drive/MyDrive/Dataset/wlasl_class_list.txt', 'r') as f:
    for line in f:
        idx, word = line.strip().split('\t')
        idx = int(idx)
        class_names.append(word)
        class_idx[word] = idx

# %%
print(f'# classes: {len(class_names)}')
print(f'First 5: {class_names[:5]}')
# Out:
# # classes: 2000
# First 5: ['book', 'drink', 'computer', 'before', 'chair']

# %%
class_idx
# Out:
# {'book': 0,
#  'drink': 1,
#  'computer': 2,
#  'before': 3,
#  'chair': 4,
#  'go': 5,
#  'clothes': 6,
#  'who': 7,
#  'candy': 8,
#  'cousin': 9,
#  'deaf': 10,
#  'fine': 11,
#  'help': 12,
#  'no': 13,
#  'thin': 14,
#  'walk': 15,
#  'year': 16,
#  'yes': 17,
#  'all': 18,
#  'black': 19,
#  'cool': 20,
#  'finish': 21,
#  'hot': 22,
#  'like': 23,
#  'many': 24,
#  'mother': 25,
#  'now': 26,
#  'orange': 27,
#  'table': 28,
#  'thanksgiving': 29,
#  'what': 30,
#  'woman': 31,
#  'bed': 32,
#  'blue': 33,
#  'bowling': 34,
#  'can': 35,
#  'dog': 36,
#  'family': 37,
#  'fish': 38,
#  'graduate': 39,
#  'hat': 40,
#  'hearing': 41,
#  'kiss': 42,
#  'language': 43,
#  'later': 44,
#  'man': 45,
#  'shirt': 46,
#  'study': 47,
#  'tall': 48,
#  'white': 49,
#  'wrong': 50,
#  'accident': 51,
#  'apple': 52,
#  'bird': 53,
#  'change': 54,
#  'color': 55,
#  'corn': 56,
#  'cow': 57,
#  'dance': 58,
#  'dark': 59,
#  'doctor': 60,
#  'eat': 61,
#  'enjoy': 62,
#  'forget': 63,
#  'give': 64,
#  'last': 65,
#  'meet': 66,
#  'pink': 67,
#  'pizza': 68,
#  'play': 69,
#  'school': 70,
#  'secretary': 71,
#  'short': 72,
#  'time': 73,
#  'want': 74,
#  'work': 75,
#  'africa': 76,
#  'basketball': 77,
#  'birthday': 78,
#  'brown': 79,
#  'but': 80,
#  'cheat': 81,
#  'city': 82,
#  'cook': 83,
#  'decide': 84,
#  'full': 85,
#  'how': 86,
#  'jacket': 87,
#  'letter': 88,
#  'medicine': 89,
#  'need': 90,
#  'paint': 91,
#  'paper': 92,
#  'pull': 93,
#  'purple': 94,
#  'right': 95,
#  'same': 96,
#  'son': 97,
#  'tell': 98,
#  'thursday': 99,
#  'visit': 100,
#  'wait': 101,
#  'water': 102,
#  'wife': 103,
#  'yellow': 104,
#  'backpack': 105,
#  'bar': 106,
#  'brother': 107,
#  'cat': 108,
#  'check': 109,
#  'class': 110,
#  'cry': 111,
#  'different': 112,
#  'door': 113,
#  'green': 114,
#  'hair': 115,
#  'have': 116,
#  'headache': 117,
#  'inform': 118,
#  'knife': 119,
#  'laugh': 120,
#  'learn': 121,
#  'movie': 122,
#  'rabbit': 123,
#  'read': 124,
#  'red': 125,
#  'room': 126,
#  'run': 127,
#  'show': 128,
#  'sick': 129,
#  'snow': 130,
#  'take': 131,
#  'tea': 132,
#  'teacher': 133,
#  'week': 134,
#  'why': 135,
#  'with': 136,
#  'write': 137,
#  'yesterday': 138,
#  'again': 139,
#  'bad': 140,
#  'ball': 141,
#  'bathroom': 142,
#  'blanket': 143,
#  'buy': 144,
#  'call': 145,
#  'coffee': 146,
#  'cold': 147,
#  'college': 148,
#  'copy': 149,
#  'cute': 150,
#  'daughter': 151,
#  'example': 152,
#  'far': 153,
#  'first': 154,
#  'friend': 155,
#  'good': 156,
#  'happy': 157,
#  'home': 158,
#  'know': 159,
#  'late': 160,
#  'leave': 161,
#  'list': 162,
#  'lose': 163,
#  'name': 164,
#  'old': 165,
#  'person': 166,
#  'police': 167,
#  'problem': 168,
#  'remember': 169,
#  'share': 170,
#  'soon': 171,
#  'stay': 172,
#  'sunday': 173,
#  'test': 174,
#  'tired': 175,
#  'trade': 176,
#  'travel': 177,
#  'window': 178,
#  'you': 179,
#  'about': 180,
#  'approve': 181,
#  'arrive': 182,
#  'balance': 183,
#  'banana': 184,
#  'beard': 185,
#  'because': 186,
#  'boy': 187,
#  'business': 188,
#  'careful': 189,
#  'center': 190,
#  'chat': 191,
#  'children': 192,
#  'christmas': 193,
#  'clock': 194,
#  'close': 195,
#  'convince': 196,
#  'country': 197,
#  'crash': 198,
#  'day': 199,
#  'discuss': 200,
#  'dress': 201,
#  'drive': 202,
#  'drop': 203,
#  'fat': 204,
#  'feel': 205,
#  'football': 206,
#  'future': 207,
#  'game': 208,
#  'girl': 209,
#  'government': 210,
#  'hear': 211,
#  'here': 212,
#  'hope': 213,
#  'house': 214,
#  'husband': 215,
#  'interest': 216,
#  'join': 217,
#  'light': 218,
#  'live': 219,
#  'make': 220,
#  'mean': 221,
#  'more': 222,
#  'most': 223,
#  'music': 224,
#  'new': 225,
#  'none': 226,
#  'office': 227,
#  'order': 228,
#  'pants': 229,
#  'party': 230,
#  'past': 231,
#  'pencil': 232,
#  'plan': 233,
#  'please': 234,
#  'practice': 235,
#  'president': 236,
#  'restaurant': 237,
#  'ride': 238,
#  'russia': 239,
#  'salt': 240,
#  'sandwich': 241,
#  'sign': 242,
#  'since': 243,
#  'small': 244,
#  'some': 245,
#  'south': 246,
#  'student': 247,
#  'teach': 248,
#  'theory': 249,
#  'tomato': 250,
#  'train': 251,
#  'ugly': 252,
#  'war': 253,
#  'where': 254,
#  'your': 255,
#  'always': 256,
#  'animal': 257,
#  'argue': 258,
#  'baby': 259,
#  'back': 260,
#  'bake': 261,
#  'bath': 262,
#  'behind': 263,
#  'bring': 264,
#  'catch': 265,
#  'cereal': 266,
#  'champion': 267,
#  'cheese': 268,
#  'cough': 269,
#  'crazy': 270,
#  'delay': 271,
#  'delicious': 272,
#  'disappear': 273,
#  'divorce': 274,
#  'draw': 275,
#  'east': 276,
#  'easy': 277,
#  'egg': 278,
#  'environment': 279,
#  'father': 280,
#  'fault': 281,
#  'flower': 282,
#  'friendly': 283,
#  'glasses': 284,
#  'halloween': 285,
#  'hard': 286,
#  'heart': 287,
#  'hour': 288,
#  'humble': 289,
#  'hurry': 290,
#  'improve': 291,
#  'internet': 292,
#  'jump': 293,
#  'kill': 294,
#  'law': 295,
#  'match': 296,
#  'meat': 297,
#  'milk': 298,
#  'money': 299,
#  'month': 300,
#  'moon': 301,
#  'move': 302,
#  'near': 303,
#  'nephew': 304,
#  'nice': 305,
#  'niece': 306,
#  'noon': 307,
#  'north': 308,
#  'not': 309,
#  'nurse': 310,
#  'off': 311,
#  'ok': 312,
#  'patient': 313,
#  'pay': 314,
#  'perspective': 315,
#  'potato': 316,
#  'sad': 317,
#  'saturday': 318,
#  'save': 319,
#  'scissors': 320,
#  'secret': 321,
#  'shoes': 322,
#  'shop': 323,
#  'silly': 324,
#  'sister': 325,
#  'sleep': 326,
#  'sorry': 327,
#  'straight': 328,
#  'sweet': 329,
#  'talk': 330,
#  'temperature': 331,
#  'tent': 332,
#  'thank you': 333,
#  'think': 334,
#  'throw': 335,
#  'today': 336,
#  'traffic': 337,
#  'understand': 338,
#  'use': 339,
#  'voice': 340,
#  'vomit': 341,
#  'vote': 342,
#  'wednesday': 343,
#  'west': 344,
#  'wet': 345,
#  'when': 346,
#  'which': 347,
#  'win': 348,
#  'word': 349,
#  'afternoon': 350,
#  'age': 351,
#  'alone': 352,
#  'appointment': 353,
#  'australia': 354,
#  'avoid': 355,
#  'balloon': 356,
#  'basement': 357,
#  'bear': 358,
#  'believe': 359,
#  'better': 360,
#  'blind': 361,
#  'bored': 362,
#  'bowl': 363,
#  'box': 364,
#  'bracelet': 365,
#  'bread': 366,
#  'cafeteria': 367,
#  'car': 368,
#  'chicken': 369,
#  'child': 370,
#  'choose': 371,
#  'church': 372,
#  'cookie': 373,
#  'cup': 374,
#  'cut': 375,
#  'decorate': 376,
#  'deep': 377,
#  'deer': 378,
#  'dentist': 379,
#  'dirty': 380,
#  'dive': 381,
#  'down': 382,
#  'dry': 383,
#  'ear': 384,
#  'earn': 385,
#  'earring': 386,
#  'elephant': 387,
#  'english': 388,
#  'escape': 389,
#  'expensive': 390,
#  'explain': 391,
#  'fast': 392,
#  'fight': 393,
#  'find': 394,
#  'fishing': 395,
#  'floor': 396,
#  'fly': 397,
#  'follow': 398,
#  'from': 399,
#  'get': 400,
#  'happen': 401,
#  'hello': 402,
#  'hit': 403,
#  'hospital': 404,
#  'idea': 405,
#  'important': 406,
#  'investigate': 407,
#  'japan': 408,
#  'jealous': 409,
#  'king': 410,
#  'kitchen': 411,
#  'large': 412,
#  'last year': 413,
#  'lemon': 414,
#  'lettuce': 415,
#  'marry': 416,
#  'meeting': 417,
#  'minute': 418,
#  'mirror': 419,
#  'miss': 420,
#  'monkey': 421,
#  'morning': 422,
#  'motorcycle': 423,
#  'necklace': 424,
#  'never': 425,
#  'newspaper': 426,
#  'night': 427,
#  'onion': 428,
#  'people': 429,
#  'pepper': 430,
#  'phone': 431,
#  'picture': 432,
#  'plus': 433,
#  'point': 434,
#  'poor': 435,
#  'possible': 436,
#  'quiet': 437,
#  'rain': 438,
#  'ready': 439,
#  'research': 440,
#  'scared': 441,
#  'science': 442,
#  'score': 443,
#  'sentence': 444,
#  'shape': 445,
#  'sit': 446,
#  'slow': 447,
#  'snake': 448,
#  'soap': 449,
#  'soda': 450,
#  'speech': 451,
#  'star': 452,
#  'stink': 453,
#  'struggle': 454,
#  'stubborn': 455,
#  'sunset': 456,
#  'surgery': 457,
#  'there': 458,
#  'tiger': 459,
#  'toast': 460,
#  'toilet': 461,
#  'tomorrow': 462,
#  'town': 463,
#  'transfer': 464,
#  'tree': 465,
#  'truck': 466,
#  'uncle': 467,
#  'vacation': 468,
#  'weather': 469,
#  'weekend': 470,
#  'accept': 471,
#  'adult': 472,
#  'after': 473,
#  'ago': 474,
#  'allow': 475,
#  'america': 476,
#  'angel': 477,
#  'answer': 478,
#  'any': 479,
#  'area': 480,
#  'art': 481,
#  'asl': 482,
#  'aunt': 483,
#  'awful': 484,
#  'awkward': 485,
#  'bacon': 486,
#  'bark': 487,
#  'bedroom': 488,
#  'beer': 489,
#  'belt': 490,
#  'big': 491,
#  'bitter': 492,
#  'both': 493,
#  'cake': 494,
#  'california': 495,
#  'canada': 496,
#  'carrot': 497,
#  'cause': 498,
#  'challenge': 499,
#  'cheap': 500,
#  'chocolate': 501,
#  'clean': 502,
#  'cloud': 503,
#  'compare': 504,
#  'complex': 505,
#  'contact': 506,
#  'continue': 507,
#  'corner': 508,
#  'correct': 509,
#  'curse': 510,
#  'dead': 511,
#  'demand': 512,
#  'depend': 513,
#  'desert': 514,
#  'desk': 515,
#  'develop': 516,
#  'dictionary': 517,
#  'doll': 518,
#  'duty': 519,
#  'easter': 520,
#  'egypt': 521,
#  'elevator': 522,
#  'email': 523,
#  'end': 524,
#  'enter': 525,
#  'europe': 526,
#  'event': 527,
#  'exchange': 528,
#  'experience': 529,
#  'face': 530,
#  'fail': 531,
#  'feed': 532,
#  'few': 533,
#  'flag': 534,
#  'food': 535,
#  'for': 536,
#  'form': 537,
#  'freeze': 538,
#  'friday': 539,
#  'front': 540,
#  'giraffe': 541,
#  'god': 542,
#  'grammar': 543,
#  'grandfather': 544,
#  'great': 545,
#  'greece': 546,
#  'guess': 547,
#  'guitar': 548,
#  'hammer': 549,
#  'helicopter': 550,
#  'high': 551,
#  'history': 552,
#  'hungry': 553,
#  'hurt': 554,
#  'introduce': 555,
#  'invest': 556,
#  'lazy': 557,
#  'library': 558,
#  'lie': 559,
#  'lobster': 560,
#  'love': 561,
#  'lucky': 562,
#  'magazine': 563,
#  'measure': 564,
#  'microwave': 565,
#  'my': 566,
#  'neighbor': 567,
#  'number': 568,
#  'one': 569,
#  'outside': 570,
#  'peach': 571,
#  'pig': 572,
#  'polite': 573,
#  'postpone': 574,
#  'power': 575,
#  'present': 576,
#  'price': 577,
#  'prison': 578,
#  'push': 579,
#  'raccoon': 580,
#  'really': 581,
#  'reason': 582,
#  'religion': 583,
#  'respect': 584,
#  'rule': 585,
#  'salad': 586,
#  'schedule': 587,
#  'sell': 588,
#  'serious': 589,
#  'shower': 590,
#  'single': 591,
#  'smart': 592,
#  'smile': 593,
#  'soft': 594,
#  'sound': 595,
#  'soup': 596,
#  'spain': 597,
#  'spray': 598,
#  'squirrel': 599,
#  'stomach': 600,
#  'story': 601,
#  'strange': 602,
#  'street': 603,
#  'stress': 604,
#  'strict': 605,
#  'strong': 606,
#  'sugar': 607,
#  'summer': 608,
#  'suspect': 609,
#  'sweetheart': 610,
#  'tease': 611,
#  'that': 612,
#  'themselves': 613,
#  'therapy': 614,
#  'thirsty': 615,
#  'ticket': 616,
#  'top': 617,
#  'tuesday': 618,
#  'turkey': 619,
#  'university': 620,
#  'until': 621,
#  'watch': 622,
#  'weak': 623,
#  'wedding': 624,
#  'will': 625,
#  'wind': 626,
#  'world': 627,
#  'worry': 628,
#  'wow': 629,
#  'young': 630,
#  'add': 631,
#  'airplane': 632,
#  'already': 633,
#  'also': 634,
#  'analyze': 635,
#  'and': 636,
#  'angry': 637,
#  'appear': 638,
#  'arm': 639,
#  'army': 640,
#  'arrest': 641,
#  'asia': 642,
#  'ask': 643,
#  'attitude': 644,
#  'attract': 645,
#  'bald': 646,
#  'barely': 647,
#  'baseball': 648,
#  'beg': 649,
#  'benefit': 650,
#  'bite': 651,
#  'blame': 652,
#  'boat': 653,
#  'body': 654,
#  'borrow': 655,
#  'boss': 656,
#  'bother': 657,
#  'bottle': 658,
#  'bottom': 659,
#  'brag': 660,
#  'build': 661,
#  'bus': 662,
#  'butter': 663,
#  'calm': 664,
#  'cancel': 665,
#  'candle': 666,
#  'cards': 667,
#  'choice': 668,
#  'comb': 669,
#  'comfortable': 670,
#  'conflict': 671,
#  'cover': 672,
#  'deodorant': 673,
#  'dessert': 674,
#  'destroy': 675,
#  'diamond': 676,
#  'dollar': 677,
#  'drawer': 678,
#  'dream': 679,
#  'drunk': 680,
#  'duck': 681,
#  'during': 682,
#  'eagle': 683,
#  'early': 684,
#  'equal': 685,
#  'every': 686,
#  'excited': 687,
#  'exercise': 688,
#  'experiment': 689,
#  'expert': 690,
#  'fact': 691,
#  'fear': 692,
#  'feedback': 693,
#  'fold': 694,
#  'forest': 695,
#  'france': 696,
#  'frog': 697,
#  'funny': 698,
#  'garage': 699,
#  'goal': 700,
#  'golf': 701,
#  'gone': 702,
#  'gossip': 703,
#  'grandmother': 704,
#  'grapes': 705,
#  'group': 706,
#  'guilty': 707,
#  'hamburger': 708,
#  'hate': 709,
#  'head': 710,
#  'her': 711,
#  'horse': 712,
#  'ignore': 713,
#  'impossible': 714,
#  'in': 715,
#  'independent': 716,
#  'inside': 717,
#  'insurance': 718,
#  'island': 719,
#  'lecture': 720,
#  'lesson': 721,
#  'limit': 722,
#  'lion': 723,
#  'listen': 724,
#  'march': 725,
#  'math': 726,
#  'maybe': 727,
#  'mechanic': 728,
#  'mom': 729,
#  'mouse': 730,
#  'much': 731,
#  'muscle': 732,
#  'museum': 733,
#  'must': 734,
#  'mustache': 735,
#  'negative': 736,
#  'nervous': 737,
#  'neutral': 738,
#  'nose': 739,
#  'often': 740,
#  'operate': 741,
#  'opinion': 742,
#  'other': 743,
#  'pass': 744,
#  'pillow': 745,
#  'prepare': 746,
#  'pretty': 747,
#  'priest': 748,
#  'program': 749,
#  'promise': 750,
#  'put': 751,
#  'queen': 752,
#  'quit': 753,
#  'radio': 754,
#  'rat': 755,
#  'reject': 756,
#  'require': 757,
#  'rest': 758,
#  'retire': 759,
#  'rise': 760,
#  'river': 761,
#  'rough': 762,
#  'see': 763,
#  'seem': 764,
#  'send': 765,
#  'sew': 766,
#  'sheep': 767,
#  'shine': 768,
#  'shock': 769,
#  'should': 770,
#  'silent': 771,
#  'skinny': 772,
#  'skirt': 773,
#  'sky': 774,
#  'sour': 775,
#  'special': 776,
#  'spirit': 777,
#  'staff': 778,
#  'stand': 779,
#  'steal': 780,
#  'stop': 781,
#  'stupid': 782,
#  'summon': 783,
#  'sunrise': 784,
#  'swallow': 785,
#  'television': 786,
#  'to': 787,
#  'together': 788,
#  'translate': 789,
#  'triangle': 790,
#  'turtle': 791,
#  'underwear': 792,
#  'up': 793,
#  'upset': 794,
#  'violin': 795,
#  'volunteer': 796,
#  'warm': 797,
#  'warn': 798,
#  'wash': 799,
#  'wine': 800,
#  'witness': 801,
#  'wood': 802,
#  'zero': 803,
#  'across': 804,
#  'actor': 805,
#  'agree': 806,
#  'alarm': 807,
#  'allergy': 808,
#  'almost': 809,
#  'announce': 810,
#  'apartment': 811,
#  'attention': 812,
#  'audience': 813,
#  'august': 814,
#  'autumn': 815,
#  'away': 816,
#  'beautiful': 817,
#  'become': 818,
#  'below': 819,
#  'best': 820,
#  'bet': 821,
#  'bicycle': 822,
#  'biology': 823,
#  'boyfriend': 824,
#  'break': 825,
#  'bridge': 826,
#  'brush': 827,
#  'building': 828,
#  'busy': 829,
#  'camera': 830,
#  'camp': 831,
#  'caption': 832,
#  'care': 833,
#  'carry': 834,
#  'celebrate': 835,
#  'certificate': 836,
#  'chain': 837,
#  'chance': 838,
#  'character': 839,
#  'chase': 840,
#  'classroom': 841,
#  'clear': 842,
#  'climb': 843,
#  'command': 844,
#  'community': 845,
#  'complain': 846,
#  'compromise': 847,
#  'contribute': 848,
#  'cop': 849,
#  'cost': 850,
#  'couch': 851,
#  'cracker': 852,
#  'curious': 853,
#  'curriculum': 854,
#  'dad': 855,
#  'deny': 856,
#  'describe': 857,
#  'diaper': 858,
#  'diarrhea': 859,
#  'disagree': 860,
#  'dissolve': 861,
#  'divide': 862,
#  'dolphin': 863,
#  'double': 864,
#  'doubt': 865,
#  'dumb': 866,
#  'earth': 867,
#  'earthquake': 868,
#  'eight': 869,
#  'embarrass': 870,
#  'emotion': 871,
#  'encourage': 872,
#  'energy': 873,
#  'enough': 874,
#  'evaluate': 875,
#  'evidence': 876,
#  'exact': 877,
#  'exaggerate': 878,
#  'expect': 879,
#  'fancy': 880,
#  'favorite': 881,
#  'finally': 882,
#  'fox': 883,
#  'french': 884,
#  'fruit': 885,
#  'function': 886,
#  'gather': 887,
#  'germany': 888,
#  'gloves': 889,
#  'goat': 890,
#  'goodbye': 891,
#  'grow': 892,
#  'gum': 893,
#  'half': 894,
#  'hawaii': 895,
#  'herself': 896,
#  'highway': 897,
#  'homework': 898,
#  'honor': 899,
#  'ice cream': 900,
#  'if': 901,
#  'increase': 902,
#  'india': 903,
#  'information': 904,
#  'interpret': 905,
#  'interview': 906,
#  'invite': 907,
#  'israel': 908,
#  'jesus': 909,
#  'keep': 910,
#  'keyboard': 911,
#  'land': 912,
#  'lawyer': 913,
#  'lead': 914,
#  'lesbian': 915,
#  'line': 916,
#  'lock': 917,
#  'loud': 918,
#  'lousy': 919,
#  'lunch': 920,
#  'machine': 921,
#  'mad': 922,
#  'memorize': 923,
#  'minus': 924,
#  'monday': 925,
#  'mountain': 926,
#  'mouth': 927,
#  'mushroom': 928,
#  'napkin': 929,
#  'neck': 930,
#  'next': 931,
#  'ocean': 932,
#  'open': 933,
#  'overwhelm': 934,
#  'owe': 935,
#  'page': 936,
#  'pain': 937,
#  'parade': 938,
#  'parents': 939,
#  'perfect': 940,
#  'period': 941,
#  'philosophy': 942,
#  'photographer': 943,
#  'place': 944,
#  'policy': 945,
#  'popular': 946,
#  'pray': 947,
#  'predict': 948,
#  'presentation': 949,
#  'print': 950,
#  'printer': 951,
#  'private': 952,
#  'procrastinate': 953,
#  'project': 954,
#  'protect': 955,
#  'prove': 956,
#  'provide': 957,
#  'psychology': 958,
#  'punish': 959,
#  'puzzled': 960,
#  'question': 961,
#  'quick': 962,
#  'rainbow': 963,
#  'rake': 964,
#  'rehearse': 965,
#  'remove': 966,
#  'revenge': 967,
#  'review': 968,
#  'rich': 969,
#  'roof': 970,
#  'rooster': 971,
#  'rude': 972,
#  'say': 973,
#  'scientist': 974,
#  'scotland': 975,
#  'screwdriver': 976,
#  'second': 977,
#  'senate': 978,
#  'separate': 979,
#  'service': 980,
#  'shrimp': 981,
#  'shy': 982,
#  'side': 983,
#  'situation': 984,
#  'slave': 985,
#  'soccer': 986,
#  'socks': 987,
#  'solid': 988,
#  'sometimes': 989,
#  'spider': 990,
#  'spin': 991,
#  'square': 992,
#  'stairs': 993,
#  'stare': 994,
#  'start': 995,
#  'store': 996,
#  'straw': 997,
#  'structure': 998,
#  'suggest': 999,
#  ...}

# %% [markdown]
# # Ground Truth - I3D (Inflated 3D ConvNet)

# %% [markdown]
# ## Setup

# %%
# !git clone https://github.com/dxli94/WLASL.git
# Out:
# Cloning into 'WLASL'...
# remote: Enumerating objects: 237, done.
# remote: Counting objects: 100% (104/104), done.
# remote: Compressing objects: 100% (51/51), done.
# remote: Total 237 (delta 65), reused 53 (delta 53), pack-reused 133 (from 2)
# Receiving objects: 100% (237/237), 3.73 MiB | 4.65 MiB/s, done.
# Resolving deltas: 100% (97/97), done.

# %%
# %cd WLASL
# !mkdir data
# Out:
# /content/WLASL

# %%
# !ls
# Out:
# code  _config.yml  data  index.md  README.md  start_kit

# %%
# !cp -r /content/drive/MyDrive/Dataset/videos_25fps.zip /content/WLASL/data

# %%
# !unzip /content/WLASL/data/videos_25fps.zip -d /content/WLASL/data/WLASL2000
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/WLASL/data/WLASL2000/27265.mp4
#   inflating: /content/WLASL/data/WLASL2000/61994.mp4
#   inflating: /content/WLASL/data/WLASL2000/01118.mp4
#   inflating: /content/WLASL/data/WLASL2000/47676.mp4
#   inflating: /content/WLASL/data/WLASL2000/59233.mp4
#   inflating: /content/WLASL/data/WLASL2000/61952.mp4
#   inflating: /content/WLASL/data/WLASL2000/69439.mp4
#   inflating: /content/WLASL/data/WLASL2000/51287.mp4
#   inflating: /content/WLASL/data/WLASL2000/65314.mp4
#   inflating: /content/WLASL/data/WLASL2000/46497.mp4
#   inflating: /content/WLASL/data/WLASL2000/33205.mp4
#   inflating: /content/WLASL/data/WLASL2000/46752.mp4
#   inflating: /content/WLASL/data/WLASL2000/52509.mp4
#   inflating: /content/WLASL/data/WLASL2000/65634.mp4
#   inflating: /content/WLASL/data/WLASL2000/28736.mp4
#   inflating: /content/WLASL/data/WLASL2000/49090.mp4
#   inflating: /content/WLASL/data/WLASL2000/47176.mp4
#   inflating: /content/WLASL/data/WLASL2000/30941.mp4
#   inflating: /content/WLASL/data/WLASL2000/38842.mp4
#   inflating: /content/WLASL/data/WLASL2000/21024.mp4
#   inflating: /content/WLASL/data/WLASL2000/13316.mp4
#   inflating: /content/WLASL/data/WLASL2000/39680.mp4
#   inflating: /content/WLASL/data/WLASL2000/69416.mp4
#   inflating: /content/WLASL/data/WLASL2000/09775.mp4
#   inflating: /content/WLASL/data/WLASL2000/12758.mp4
#   inflating: /content/WLASL/data/WLASL2000/21283.mp4
#   inflating: /content/WLASL/data/WLASL2000/47273.mp4
#   inflating: /content/WLASL/data/WLASL2000/19410.mp4
#   inflating: /content/WLASL/data/WLASL2000/44628.mp4
#   inflating: /content/WLASL/data/WLASL2000/49089.mp4
#   inflating: /content/WLASL/data/WLASL2000/65804.mp4
#   inflating: /content/WLASL/data/WLASL2000/49644.mp4
#   inflating: /content/WLASL/data/WLASL2000/35556.mp4
#   inflating: /content/WLASL/data/WLASL2000/49318.mp4
0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from gdown) (4.13.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from gdown) (3.18.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.11/dist-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from gdown) (4.67.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (2025.4.26)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (1.7.1)
# Downloading...
# From (original): https://drive.google.com/uc?id=1JgTRHGBRCHyHRT_rAF0fOjnfiFefXkEd
# From (redirected): https://drive.google.com/uc?id=1JgTRHGBRCHyHRT_rAF0fOjnfiFefXkEd&confirm=t&uuid=69b2bea0-978f-4bdd-8585-9bd574daa976
# To: /content/WLASL/weights.zip
# 100% 187M/187M [00:01<00:00, 104MB/s]

# %%
# !unzip weights.zip
# Out:
# Archive:  weights.zip
#    creating: weights/
#   inflating: weights/flow_charades.pt
#   inflating: weights/rgb_imagenet.pt
#   inflating: weights/rgb_charades.pt
#   inflating: weights/flow_imagenet.pt

# %% [markdown]
# ## Training

# %%
# %cd /content/WLASL/code/I3D
# !mkdir checkpoints
# Out:
# /content/WLASL/code/I3D
# mkdir: cannot create directory ‘checkpoints’: File exists

# %%
# %%writefile train_i3d.py
import json
import math
import os
import os.path
import random

import cv2
import numpy as np
import torch
import torch.utils.data as data_utl


def video_to_tensor(pic):
    """Convert a ``numpy.ndarray`` to tensor.
    Converts a numpy.ndarray (T x H x W x C)
    to a torch.FloatTensor of shape (C x T x H x W)

    Args:
         pic (numpy.ndarray): Video to be converted to tensor.
    Returns:
         Tensor: Converted video.
    """
    return torch.from_numpy(pic.transpose([3, 0, 1, 2]))


def load_rgb_frames(image_dir, vid, start, num):
    frames = []
    for i in range(start, start + num):
        try:
            img = cv2.imread(os.path.join(image_dir, vid, "image_" + str(i).zfill(5) + '.jpg'))[:, :, [2, 1, 0]]
        except:
            print(os.path.join(image_dir, vid, str(i).zfill(6) + '.jpg'))
        w, h, c = img.shape
        if w < 226 or h < 226:
            d = 226. - min(w, h)
            sc = 1 + d / min(w, h)
            img = cv2.resize(img, dsize=(0, 0), fx=sc, fy=sc)
        img = (img / 255.) * 2 - 1
        frames.append(img)
    return np.asarray(frames, dtype=np.float32)


def load_rgb_frames_from_video(vid_root, vid, start, num, resize=(256, 256)):
    video_path = os.path.join(vid_root, vid + '.mp4')

    vidcap = cv2.VideoCapture(video_path)

    frames = []

    total_frames = vidcap.get(cv2.CAP_PROP_FRAME_COUNT)

    vidcap.set(cv2.CAP_PROP_POS_FRAMES, start)
    for offset in range(min(num, int(total_frames - start))):
        success, img = vidcap.read()

        w, h, c = img.shape
        if w < 226 or h < 226:
            d = 226. - min(w, h)
            sc = 1 + d / min(w, h)
            img = cv2.resize(img, dsize=(0, 0), fx=sc, fy=sc)

        if w > 256 or h > 256:
            img = cv2.resize(img, (math.ceil(w * (256 / w)), math.ceil(h * (256 / h))))

        img = (img / 255.) * 2 - 1

        frames.append(img)

    return np.asarray(frames, dtype=np.float32)


def load_flow_frames(image_dir, vid, start, num):
    frames = []
    for i in range(start, start + num):
        imgx = cv2.imread(os.path.join(image_dir, vid, vid + '-' + str(i).zfill(6) + 'x.jpg'), cv2.IMREAD_GRAYSCALE)
        imgy = cv2.imread(os.path.join(image_dir, vid, vid + '-' + str(i).zfill(6) + 'y.jpg'), cv2.IMREAD_GRAYSCALE)

        w, h = imgx.shape
        if w < 224 or h < 224:
            d = 224. - min(w, h)
            sc = 1 + d / min(w, h)
            imgx = cv2.resize(imgx, dsize=(0, 0), fx=sc, fy=sc)
            imgy = cv2.resize(imgy, dsize=(0, 0), fx=sc, fy=sc)

        imgx = (imgx / 255.) * 2 - 1
        imgy = (imgy / 255.) * 2 - 1
        img = np.asarray([imgx, imgy]).transpose([1, 2, 0])
        frames.append(img)
    return np.asarray(frames, dtype=np.float32)


def make_dataset(split_file, split, root, mode, num_classes):
    dataset = []
    with open(split_file, 'r') as f:
        data = json.load(f)

    i = 0
    count_skipping = 0
    for vid in data.keys():
        if split == 'train':
            if data[vid]['subset'] not in ['train', 'val']:
                continue
        else:
            if data[vid]['subset'] != 'test':
                continue

        vid_root = root['word']
        src = 0

        video_path = os.path.join(vid_root, vid + '.mp4')
        if not os.path.exists(video_path):
            continue

        num_frames = int(cv2.VideoCapture(video_path).get(cv2.CAP_PROP_FRAME_COUNT))

        if mode == 'flow':
            num_frames = num_frames // 2

        if num_frames - 0 < 9:
            print("Skip video ", vid)
            count_skipping += 1
            continue

        label = np.zeros((num_classes, num_frames), np.float32)

        for l in range(num_frames):
            c_ = data[vid]['action'][0]
            label[c_][l] = 1

        if len(vid) == 5:
            dataset.append((vid, label, src, 0, data[vid]['action'][2] - data[vid]['action'][1]))
        elif len(vid) == 6:  ## sign kws instances
            dataset.append((vid, label, src, data[vid]['action'][1], data[vid]['action'][2] - data[vid]['action'][1]))

        i += 1
    print("Skipped videos: ", count_skipping)
    print(len(dataset))
    return dataset


def get_num_class(split_file):
    classes = set()

    content = json.load(open(split_file))

    for vid in content.keys():
        class_id = content[vid]['action'][0]
        classes.add(class_id)

    return len(classes)


class NSLT(data_utl.Dataset):

    def __init__(self, split_file, split, root, mode, transforms=None):
        self.num_classes = get_num_class(split_file)

        self.data = make_dataset(split_file, split, root, mode, num_classes=self.num_classes)
        self.split_file = split_file
        self.transforms = transforms
        self.mode = mode
        self.root = root

    def __getitem__(self, index):
        """
        Args:
            index (int): Index

        Returns:
            tuple: (image, target) where target is class_index of the target class.
        """
        vid, label, src, start_frame, nf = self.data[index]

        total_frames = 64

        try:
            start_f = random.randint(0, nf - total_frames - 1) + start_frame
        except ValueError:
            start_f = start_frame

        imgs = load_rgb_frames_from_video(self.root['word'], vid, start_f, total_frames)

        imgs, label = self.pad(imgs, label, total_frames)

        imgs = self.transforms(imgs)

        ret_lab = torch.from_numpy(label)
        ret_img = video_to_tensor(imgs)

        return ret_img, ret_lab, vid

    def __len__(self):
        return len(self.data)

    def pad(self, imgs, label, total_frames):
        if imgs.shape[0] < total_frames:
            num_padding = total_frames - imgs.shape[0]

            if num_padding:
                prob = np.random.random_sample()
                if prob > 0.5:
                    pad_img = imgs[0]
                    pad = np.tile(np.expand_dims(pad_img, axis=0), (num_padding, 1, 1, 1))
                    padded_imgs = np.concatenate([imgs, pad], axis=0)
                else:
                    pad_img = imgs[-1]
                    pad = np.tile(np.expand_dims(pad_img, axis=0), (num_padding, 1, 1, 1))
                    padded_imgs = np.concatenate([imgs, pad], axis=0)
        else:
            padded_imgs = imgs

        label = label[:, 0]
        label = np.tile(label, (total_frames, 1)).transpose((1, 0))

        return padded_imgs, label

    @staticmethod
    def pad_wrap(imgs, label, total_frames):
        if imgs.shape[0] < total_frames:
            num_padding = total_frames - imgs.shape[0]

            if num_padding:
                pad = imgs[:min(num_padding, imgs.shape[0])]
                k = num_padding // imgs.shape[0]
                tail = num_padding % imgs.shape[0]

                pad2 = imgs[:tail]
                if k > 0:
                    pad1 = np.array(k * [pad])[0]

                    padded_imgs = np.concatenate([imgs, pad1, pad2], axis=0)
                else:
                    padded_imgs = np.concatenate([imgs, pad2], axis=0)
        else:
            padded_imgs = imgs

        label = label[:, 0]
        label = np.tile(label, (total_frames, 1)).transpose((1, 0))

        return padded_imgs, label

#--------------------------------------------------

import os
import argparse

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable
from torch.optim.lr_scheduler import StepLR, MultiStepLR

from torchvision import transforms
import videotransforms

import numpy as np

from configs import Config
from pytorch_i3d import InceptionI3d

# from datasets.nslt_dataset import NSLT as Dataset

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = '0'

parser = argparse.ArgumentParser()
parser.add_argument('-mode', type=str, help='rgb or flow')
parser.add_argument('-save_model', type=str)
parser.add_argument('-root', type=str)
parser.add_argument('--num_class', type=int)

args = parser.parse_args()

torch.manual_seed(0)
np.random.seed(0)

torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False


def run(configs,
        mode='rgb',
        root='/ssd/Charades_v1_rgb',
        train_split='charades/charades.json',
        save_model='',
        weights=None):
    print(configs)

    # setup dataset
    train_transforms = transforms.Compose([videotransforms.RandomCrop(224),
                                           videotransforms.RandomHorizontalFlip(), ])
    test_transforms = transforms.Compose([videotransforms.CenterCrop(224)])

    dataset = NSLT(train_split, 'train', root, mode, train_transforms)
    dataloader = torch.utils.data.DataLoader(dataset, batch_size=configs.batch_size, shuffle=True, num_workers=0,
                                             pin_memory=True)

    val_dataset = NSLT(train_split, 'test', root, mode, test_transforms)
    val_dataloader = torch.utils.data.DataLoader(val_dataset, batch_size=configs.batch_size, shuffle=True, num_workers=2,
                                                 pin_memory=False)

    dataloaders = {'train': dataloader, 'test': val_dataloader}
    datasets = {'train': dataset, 'test': val_dataset}

    # setup the model
    if mode == 'flow':
        i3d = InceptionI3d(400, in_channels=2)
        i3d.load_state_dict(torch.load('/content/WLASL/weights/flow_imagenet.pt'))
    else:
        i3d = InceptionI3d(400, in_channels=3)
        i3d.load_state_dict(torch.load('/content/WLASL/weights/rgb_imagenet.pt'))

    num_classes = dataset.num_classes
    i3d.replace_logits(num_classes)

    if weights:
        print('loading weights {}'.format(weights))
        i3d.load_state_dict(torch.load(weights))

    i3d.cuda()
    i3d = nn.DataParallel(i3d)

    lr = configs.init_lr
    weight_decay = configs.adam_weight_decay
    optimizer = optim.Adam(i3d.parameters(), lr=lr, weight_decay=weight_decay)

    num_steps_per_update = configs.update_per_step  # accum gradient
    steps = 0
    epoch = 0

    best_val_score = 0
    # train it
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=5, factor=0.3)
    while steps < configs.max_steps and epoch < 400:  # for epoch in range(num_epochs):
        print('Step {}/{}'.format(steps, configs.max_steps))
        print('-' * 10)

        epoch += 1
        # Each epoch has a training and validation phase
        for phase in ['train', 'test']:
            collected_vids = []

            if phase == 'train':
                i3d.train(True)
            else:
                i3d.train(False)  # Set model to evaluate mode

            tot_loss = 0.0
            tot_loc_loss = 0.0
            tot_cls_loss = 0.0
            num_iter = 0
            optimizer.zero_grad()

            confusion_matrix = np.zeros((num_classes, num_classes), dtype=np.int64)
            # Iterate over data.
            for data in dataloaders[phase]:
                num_iter += 1
                # get the inputs
                if data == -1: # bracewell does not compile opencv with ffmpeg, strange errors occur resulting in no video loaded
                    continue

                # inputs, labels, vid, src = data
                inputs, labels, vid = data

                # wrap them in Variable
                inputs = inputs.cuda()
                t = inputs.size(2)
                labels = labels.cuda()

                per_frame_logits = i3d(inputs, pretrained=False)
                # upsample to input size
                per_frame_logits = F.upsample(per_frame_logits, t, mode='linear')

                # compute localization loss
                loc_loss = F.binary_cross_entropy_with_logits(per_frame_logits, labels)
                tot_loc_loss += loc_loss.data.item()

                predictions = torch.max(per_frame_logits, dim=2)[0]
                gt = torch.max(labels, dim=2)[0]

                # compute classification loss (with max-pooling along time B x C x T)
                cls_loss = F.binary_cross_entropy_with_logits(torch.max(per_frame_logits, dim=2)[0],
                                                              torch.max(labels, dim=2)[0])
                tot_cls_loss += cls_loss.data.item()

                for i in range(per_frame_logits.shape[0]):
                    confusion_matrix[torch.argmax(gt[i]).item(), torch.argmax(predictions[i]).item()] += 1

                loss = (0.5 * loc_loss + 0.5 * cls_loss) / num_steps_per_update
                tot_loss += loss.data.item()
                if num_iter == num_steps_per_update // 2:
                    print(epoch, steps, loss.data.item())
                loss.backward()

                if num_iter == num_steps_per_update and phase == 'train':
                    steps += 1
                    num_iter = 0
                    optimizer.step()
                    optimizer.zero_grad()
                    # lr_sched.step()
                    if steps % 10 == 0:
                        acc = float(np.trace(confusion_matrix)) / np.sum(confusion_matrix)
                        print(
                            'Epoch {} {} Loc Loss: {:.4f} Cls Loss: {:.4f} Tot Loss: {:.4f} Accu :{:.4f}'.format(epoch,
                                                                                                                 phase,
                                                                                                                 tot_loc_loss / (10 * num_steps_per_update),
                                                                                                                 tot_cls_loss / (10 * num_steps_per_update),
                                                                                                                 tot_loss / 10,
                                                                                                                 acc))
                        tot_loss = tot_loc_loss = tot_cls_loss = 0.
            if phase == 'test':
                val_score = float(np.trace(confusion_matrix)) / np.sum(confusion_matrix)
                if val_score > best_val_score or epoch % 2 == 0:
                    best_val_score = val_score
                    model_name = save_model + "nslt_" + str(num_classes) + "_" + str(steps).zfill(
                                   6) + '_%3f.pt' % val_score

                    torch.save(i3d.module.state_dict(), model_name)
                    print(model_name)

                print('VALIDATION: {} Loc Loss: {:.4f} Cls Loss: {:.4f} Tot Loss: {:.4f} Accu :{:.4f}'.format(phase,
                                                                                                              tot_loc_loss / num_iter,
                                                                                                              tot_cls_loss / num_iter,
                                                                                                              (tot_loss * num_steps_per_update) / num_iter,
                                                                                                              val_score
                                                                                                              ))

                scheduler.step(tot_loss * num_steps_per_update / num_iter)


if __name__ == '__main__':
    # WLASL setting
    mode = 'rgb'
    root = {'word': '../../data/WLASL2000'}

    save_model = '/content/WLASL/code/I3D/checkpoints/'
    train_split = '/content/WLASL/code/I3D/preprocess/nslt_100.json'

    # weights = 'archived/asl2000/FINAL_nslt_2000_iters=5104_top1=32.48_top5=57.31_top10=66.31.pt'
    weights = None
    config_file = '/content/WLASL/code/I3D/configfiles/asl100.ini'

    configs = Config(config_file)
    print(root, train_split)
    run(configs=configs, mode=mode, root=root, save_model=save_model, train_split=train_split, weights=weights)
# Out:
# Overwriting train_i3d.py

# %%
# !ls
# Out:
# checkpoints  configs.py  models      pytorch_i3d.py  train_i3d.py
# configfiles  datasets	 preprocess  test_i3d.py     videotransforms.py

# %%
# !ls -l /content/WLASL/code/I3D/datasets
# Out:
# total 20
# -rw-r--r-- 1 root root 5004 May 15 11:22 nslt_dataset_all.py
# -rw-r--r-- 1 root root 7254 May 15 11:22 nslt_dataset.py
# drwxr-xr-x 2 root root 4096 May 15 11:22 __pycache__

# %%
# !python train_i3d.py
# Out:
# {'word': '../../data/WLASL2000'} /content/WLASL/code/I3D/preprocess/nslt_100.json
# bs=6_ups=1_lr=0.001_eps=0.001_wd=1e-07
# Skipped videos:  0
# 913
# Skipped videos:  0
# 100
# Step 0/6000
# ----------
# /content/WLASL/code/I3D/train_i3d.py:373: UserWarning: `nn.functional.upsample` is deprecated. Use `nn.functional.interpolate` instead.
#   per_frame_logits = F.upsample(per_frame_logits, t, mode='linear')
# Epoch 1 train Loc Loss: 0.3846 Cls Loss: 0.4519 Tot Loss: 0.4183 Accu :0.0167
# Epoch 1 train Loc Loss: 0.0800 Cls Loss: 0.0980 Tot Loss: 0.0890 Accu :0.0250
# Epoch 1 train Loc Loss: 0.0575 Cls Loss: 0.0588 Tot Loss: 0.0582 Accu :0.0167
# Epoch 1 train Loc Loss: 0.0591 Cls Loss: 0.0570 Tot Loss: 0.0580 Accu :0.0208
# Epoch 1 train Loc Loss: 0.0597 Cls Loss: 0.0569 Tot Loss: 0.0583 Accu :0.0167
# Epoch 1 train Loc Loss: 0.0590 Cls Loss: 0.0565 Tot Loss: 0.0577 Accu :0.0194
# Epoch 20 train Loc Loss: 0.0145 Cls Loss: 0.0071 Tot Loss: 0.0108 Accu :0.9315
# Epoch 20 train Loc Loss: 0.0120 Cls Loss: 0.0073 Tot Loss: 0.0097 Accu :0.9357
# Epoch 20 train Loc Loss: 0.0137 Cls Loss: 0.0079 Tot Loss: 0.0108 Accu :0.9337
# Epoch 20 train Loc Loss: 0.0144 Cls Loss: 0.0074 Tot Loss: 0.0109 Accu :0.9337
# Epoch 20 train Loc Loss: 0.0144 Cls Loss: 0.0093 Tot Loss: 0.0119 Accu :0.9307
# Epoch 20 train Loc Loss: 0.0145 Cls Loss: 0.0070 Tot Loss: 0.0107 Accu :0.9322
# Epoch 20 train Loc Loss: 0.0129 Cls Loss: 0.0082 Tot Loss: 0.0105 Accu :0.9336
# Epoch 20 train Loc Loss: 0.0130 Cls Loss: 0.0073 Tot Loss: 0.0101 Accu :0.9359
# Epoch 20 train Loc Loss: 0.0236 Cls Loss: 0.0090 Tot Loss: 0.0163 Accu :0.9343
# /content/WLASL/code/I3D/checkpoints/nslt_100_003060_0.500000.pt
# VALIDATION: test Loc Loss: 0.0354 Cls Loss: 0.0343 Tot Loss: 0.0349 Accu :0.5000
# Step 3060/6000
# ----------
# Epoch 21 train Loc Loss: 0.0114 Cls Loss: 0.0069 Tot Loss: 0.0091 Accu :0.9833
# Epoch 21 train Loc Loss: 0.0149 Cls Loss: 0.0081 Tot Loss: 0.0115 Accu :0.9500
# Epoch 21 train Loc Loss: 0.0116 Cls Loss: 0.0072 Tot Loss: 0.0094 Accu :0.9444
# Epoch 21 train Loc Loss: 0.0118 Cls Loss: 0.0067 Tot Loss: 0.0093 Accu :0.9500
# Epoch 21 train Loc Loss: 0.0127 Cls Loss: 0.0065 Tot Loss: 0.0096 Accu :0.9500
# Epoch 21 train Loc Loss: 0.0094 Cls Loss: 0.0048 Tot Loss: 0.0071 Accu :0.9583
# Epoch 21 train Loc Loss: 0.0135 Cls Loss: 0.0075 Tot Loss: 0.0105 Accu :0.9571
# Epoch 21 train Loc Loss: 0.0122 Cls Loss: 0.0064 Tot Loss: 0.0093 Accu :0.9583
# Epoch 21 train Loc Loss: 0.0130 Cls Loss: 0.0072 Tot Loss: 0.0101 Accu :0.9574
# Epoch 21 train Loc Loss: 0.0103 Cls Loss: 0.0074 Tot Loss: 0.0089 Accu :0.9583
# Epoch 21 train Loc Loss: 0.0151 Cls Loss: 0.0077 Tot Loss: 0.0114 Accu :0.9591
# Epoch 21 train Loc Loss: 0.0150 Cls Loss: 0.0086 Tot Loss: 0.0118 Accu :0.9597
# Epoch 21 train Loc Loss: 0.0102 Cls Loss: 0.0062 Tot Loss: 0.0082 Accu :0.9603
# Epoch 21 train Loc Loss: 0.0150 Cls Loss: 0.0088 Tot Loss: 0.0119 Accu :0.9548
# Epoch 21 train Loc Loss: 0.0124 Cls Loss: 0.0073 Tot Loss: 0.0099 Accu :0.9522
# VALIDATION: test Loc Loss: 0.0395 Cls Loss: 0.0368 Tot Loss: 0.0382 Accu :0.4700
# Epoch 25 train Loc Loss: 0.0068 Cls Loss: 0.0035 Tot Loss: 0.0052 Accu :0.9881
# Epoch 25 train Loc Loss: 0.0055 Cls Loss: 0.0029 Tot Loss: 0.0042 Accu :0.9912
# Epoch 25 train Loc Loss: 0.0057 Cls Loss: 0.0028 Tot Loss: 0.0043 Accu :0.9931
# Epoch 25 train Loc Loss: 0.0055 Cls Loss: 0.0030 Tot Loss: 0.0042 Accu :0.9914
# Epoch 25 train Loc Loss: 0.0068 Cls Loss: 0.0033 Tot Loss: 0.0050 Accu :0.9902
# Epoch 25 train Loc Loss: 0.0067 Cls Loss: 0.0030 Tot Loss: 0.0048 Accu :0.9915
# Epoch 25 train Loc Loss: 0.0052 Cls Loss: 0.0029 Tot Loss: 0.0040 Accu :0.9905
# Epoch 25 train Loc Loss: 0.0053 Cls Loss: 0.0034 Tot Loss: 0.0044 Accu :0.9898
# Epoch 25 train Loc Loss: 0.0070 Cls Loss: 0.0044 Tot Loss: 0.0057 Accu :0.9892
# Epoch 25 train Loc Loss: 0.0050 Cls Loss: 0.0030 Tot Loss: 0.0040 Accu :0.9887
# Epoch 25 train Loc Loss: 0.0082 Cls Loss: 0.0048 Tot Loss: 0.0065 Accu :0.9883
# Epoch 25 train Loc Loss: 0.0055 Cls Loss: 0.0036 Tot Loss: 0.0045 Accu :0.9879
# Epoch 25 train Loc Loss: 0.0087 Cls Loss: 0.0031 Tot Loss: 0.0059 Accu :0.9887
# /content/WLASL/code/I3D/checkpoints/nslt_100_003825_0.630000.pt
# VALIDATION: test Loc Loss: 0.0291 Cls Loss: 0.0269 Tot Loss: 0.0280 Accu :0.6300
# Step 3825/6000
# ----------
# Epoch 26 train Loc Loss: 0.0031 Cls Loss: 0.0014 Tot Loss: 0.0022 Accu :1.0000
# Epoch 26 train Loc Loss: 0.0052 Cls Loss: 0.0032 Tot Loss: 0.0042 Accu :0.9889
# Epoch 26 train Loc Loss: 0.0074 Cls Loss: 0.0036 Tot Loss: 0.0055 Accu :0.9867
# Epoch 26 train Loc Loss: 0.0058 Cls Loss: 0.0025 Tot Loss: 0.0042 Accu :0.9905
# Epoch 26 train Loc Loss: 0.0056 Cls Loss: 0.0028 Tot Loss: 0.0042 Accu :0.9926
# Epoch 26 train Loc Loss: 0.0051 Cls Loss: 0.0023 Tot Loss: 0.0037 Accu :0.9939
# Epoch 26 train Loc Loss: 0.0057 Cls Loss: 0.0025 Tot Loss: 0.0041 Accu :0.9949
# Epoch 26 train Loc Loss: 0.0051 Cls Loss: 0.0028 Tot Loss: 0.0039 Accu :0.9956
# Epoch 26 train Loc Loss: 0.0054 Cls Loss: 0.0031 Tot Loss: 0.0043 Accu :0.9941
# Epoch 26 train Loc Loss: 0.0049 Cls Loss: 0.0030 Tot Loss: 0.0040 Accu :0.9930
# Epoch 26 train Loc Loss: 0.0054 Cls Loss: 0.0023 Tot Loss: 0.0038 Accu :0.9937
# Epoch 26 train Loc Loss: 0.0063 Cls Loss: 0.0037 Tot Loss: 0.0050 Accu :0.9928
# Epoch 26 train Loc Loss: 0.0057 Cls Loss: 0.0029 Tot Loss: 0.0043 Accu :0.9933
# Epoch 26 train Loc Loss: 0.0055 Cls Loss: 0.0029 Tot Loss: 0.0042 Accu :0.9938
# Epoch 26 train Loc Loss: 0.0050 Cls Loss: 0.0028 Tot Loss: 0.0039 Accu :0.9931
# /content/WLASL/code/I3D/checkpoints/nslt_100_003978_0.560000.pt
# VALIDATION: test Loc Loss: 0.0290 Cls Loss: 0.0267 Tot Loss: 0.0279 Accu :0.5600
# Step 3978/6000
# ----------
# Epoch 27 train Loc Loss: 0.0010 Cls Loss: 0.0004 Tot Loss: 0.0007 Accu :1.0000
# Epoch 27 train Loc Loss: 0.0056 Cls Loss: 0.0027 Tot Loss: 0.0041 Accu :0.9861
# Epoch 27 train Loc Loss: 0.0049 Cls Loss: 0.0025 Tot Loss: 0.0037 Accu :0.9848
# Epoch 27 train Loc Loss: 0.0051 Cls Loss: 0.0028 Tot Loss: 0.0039 Accu :0.9844
# Epoch 27 train Loc Loss: 0.0045 Cls Loss: 0.0024 Tot Loss: 0.0034 Accu :0.9881
# Epoch 27 train Loc Loss: 0.0041 Cls Loss: 0.0028 Tot Loss: 0.0034 Accu :0.9872
# Epoch 27 train Loc Loss: 0.0050 Cls Loss: 0.0025 Tot Loss: 0.0038 Accu :0.9892
# Epoch 27 train Loc Loss: 0.0049 Cls Loss: 0.0026 Tot Loss: 0.0037 Accu :0.9884
# Epoch 27 train Loc Loss: 0.0068 Cls Loss: 0.0031 Tot Loss: 0.0050 Accu :0.9898
# Epoch 27 train Loc Loss: 0.0049 Cls Loss: 0.0028 Tot Loss: 0.0038 Accu :0.9909
# Epoch 27 train Loc Loss: 0.0052 Cls Loss: 0.0026 Tot Loss: 0.0039 Accu :0.9918
# Epoch 27 train Loc Loss: 0.0045 Cls Loss: 0.0026 Tot Loss: 0.0035 Accu :0.9911
# Epoch 27 train Loc Loss: 0.0041 Cls Loss: 0.0030 Tot Loss: 0.0036 Accu :0.9918
# Epoch 27 train Loc Loss: 0.0047 Cls Loss: 0.0031 Tot Loss: 0.0039 Accu :0.9912
# Epoch 27 train Loc Loss: 0.0046 Cls Loss: 0.0025 Tot Loss: 0.0036 Accu :0.9906
# Epoch 27 train Loc Loss: 0.0054 Cls Loss: 0.0028 Tot Loss: 0.0041 Accu :0.9901
# /content/WLASL/code/I3D/checkpoints/nslt_100_004131_0.570000.pt
# VALIDATION: test Loc Loss: 0.0299 Cls Loss: 0.0277 Tot Loss: 0.0288 Accu :0.5700
# Step 4131/6000
# ----------
# Epoch 28 train Loc Loss: 0.0040 Cls Loss: 0.0018 Tot Loss: 0.0029 Accu :1.0000
# Epoch 28 train Loc Loss: 0.0049 Cls Loss: 0.0025 Tot Loss: 0.0037 Accu :0.9912
# Epoch 28 train Loc Loss: 0.0037 Cls Loss: 0.0022 Tot Loss: 0.0029 Accu :0.9943
# Epoch 28 train Loc Loss: 0.0043 Cls Loss: 0.0017 Tot Loss: 0.0030 Accu :0.9957
# Epoch 31 train Loc Loss: 0.0049 Cls Loss: 0.0023 Tot Loss: 0.0036 Accu :0.9976
# Epoch 31 train Loc Loss: 0.0032 Cls Loss: 0.0019 Tot Loss: 0.0026 Accu :0.9979
# Epoch 31 train Loc Loss: 0.0036 Cls Loss: 0.0015 Tot Loss: 0.0026 Accu :0.9981
# Epoch 31 train Loc Loss: 0.0045 Cls Loss: 0.0020 Tot Loss: 0.0033 Accu :0.9983
# Epoch 31 train Loc Loss: 0.0041 Cls Loss: 0.0032 Tot Loss: 0.0036 Accu :0.9970
# Epoch 31 train Loc Loss: 0.0053 Cls Loss: 0.0030 Tot Loss: 0.0042 Accu :0.9931
# Epoch 31 train Loc Loss: 0.0044 Cls Loss: 0.0020 Tot Loss: 0.0032 Accu :0.9936
# Epoch 31 train Loc Loss: 0.0036 Cls Loss: 0.0021 Tot Loss: 0.0029 Accu :0.9940
# Epoch 31 train Loc Loss: 0.0044 Cls Loss: 0.0030 Tot Loss: 0.0037 Accu :0.9933
# /content/WLASL/code/I3D/checkpoints/nslt_100_004743_0.580000.pt
# VALIDATION: test Loc Loss: 0.0309 Cls Loss: 0.0297 Tot Loss: 0.0303 Accu :0.5800
# Step 4743/6000
# ----------
# Epoch 32 train Loc Loss: 0.0030 Cls Loss: 0.0013 Tot Loss: 0.0021 Accu :1.0000
# Epoch 32 train Loc Loss: 0.0040 Cls Loss: 0.0017 Tot Loss: 0.0028 Accu :1.0000
# Epoch 32 train Loc Loss: 0.0050 Cls Loss: 0.0024 Tot Loss: 0.0037 Accu :0.9938
# Epoch 32 train Loc Loss: 0.0030 Cls Loss: 0.0017 Tot Loss: 0.0024 Accu :0.9955
# Epoch 32 train Loc Loss: 0.0035 Cls Loss: 0.0018 Tot Loss: 0.0027 Accu :0.9965
# Epoch 32 train Loc Loss: 0.0037 Cls Loss: 0.0026 Tot Loss: 0.0032 Accu :0.9942
# Epoch 32 train Loc Loss: 0.0033 Cls Loss: 0.0019 Tot Loss: 0.0026 Accu :0.9950
# Epoch 32 train Loc Loss: 0.0058 Cls Loss: 0.0029 Tot Loss: 0.0044 Accu :0.9935
# Epoch 32 train Loc Loss: 0.0040 Cls Loss: 0.0025 Tot Loss: 0.0032 Accu :0.9923
# Epoch 32 train Loc Loss: 0.0037 Cls Loss: 0.0029 Tot Loss: 0.0033 Accu :0.9931
# Epoch 32 train Loc Loss: 0.0034 Cls Loss: 0.0016 Tot Loss: 0.0025 Accu :0.9938
# Epoch 32 train Loc Loss: 0.0035 Cls Loss: 0.0023 Tot Loss: 0.0029 Accu :0.9943
# Epoch 32 train Loc Loss: 0.0028 Cls Loss: 0.0019 Tot Loss: 0.0024 Accu :0.9934
# Epoch 32 train Loc Loss: 0.0035 Cls Loss: 0.0016 Tot Loss: 0.0026 Accu :0.9939
# Epoch 32 train Loc Loss: 0.0034 Cls Loss: 0.0017 Tot Loss: 0.0026 Accu :0.9943
# /content/WLASL/code/I3D/checkpoints/nslt_100_004896_0.570000.pt
# VALIDATION: test Loc Loss: 0.0294 Cls Loss: 0.0281 Tot Loss: 0.0288 Accu :0.5700
# Epoch 34 train Loc Loss: 0.0031 Cls Loss: 0.0013 Tot Loss: 0.0022 Accu :0.9967
# Epoch 34 train Loc Loss: 0.0030 Cls Loss: 0.0013 Tot Loss: 0.0021 Accu :0.9970
# Epoch 34 train Loc Loss: 0.0028 Cls Loss: 0.0016 Tot Loss: 0.0022 Accu :0.9959
# Epoch 34 train Loc Loss: 0.0043 Cls Loss: 0.0026 Tot Loss: 0.0035 Accu :0.9936
# Epoch 34 train Loc Loss: 0.0035 Cls Loss: 0.0016 Tot Loss: 0.0025 Accu :0.9941
# Epoch 34 train Loc Loss: 0.0031 Cls Loss: 0.0022 Tot Loss: 0.0027 Accu :0.9934
# /content/WLASL/code/I3D/checkpoints/nslt_100_005202_0.540000.pt
# VALIDATION: test Loc Loss: 0.0298 Cls Loss: 0.0279 Tot Loss: 0.0289 Accu :0.5400
# Step 5202/6000
# ----------
# Epoch 35 train Loc Loss: 0.0016 Cls Loss: 0.0009 Tot Loss: 0.0012 Accu :1.0000
# Epoch 35 train Loc Loss: 0.0031 Cls Loss: 0.0019 Tot Loss: 0.0025 Accu :0.9907
# Epoch 35 train Loc Loss: 0.0024 Cls Loss: 0.0016 Tot Loss: 0.0020 Accu :0.9940
# Epoch 35 train Loc Loss: 0.0048 Cls Loss: 0.0015 Tot Loss: 0.0031 Accu :0.9956
# Epoch 35 train Loc Loss: 0.0031 Cls Loss: 0.0016 Tot Loss: 0.0023 Accu :0.9965
# Epoch 35 train Loc Loss: 0.0039 Cls Loss: 0.0021 Tot Loss: 0.0030 Accu :0.9943
# Epoch 35 train Loc Loss: 0.0016 Cls Loss: 0.0013 Tot Loss: 0.0014 Accu :0.9951
# Epoch 35 train Loc Loss: 0.0035 Cls Loss: 0.0017 Tot Loss: 0.0026 Accu :0.9936
# Epoch 35 train Loc Loss: 0.0021 Cls Loss: 0.0011 Tot Loss: 0.0016 Accu :0.9943
# Epoch 35 train Loc Loss: 0.0040 Cls Loss: 0.0018 Tot Loss: 0.0029 Accu :0.9932
# Epoch 35 train Loc Loss: 0.0021 Cls Loss: 0.0016 Tot Loss: 0.0019 Accu :0.9938
# Epoch 35 train Loc Loss: 0.0032 Cls Loss: 0.0014 Tot Loss: 0.0023 Accu :0.9944
# Epoch 35 train Loc Loss: 0.0024 Cls Loss: 0.0012 Tot Loss: 0.0018 Accu :0.9948
# Epoch 35 train Loc Loss: 0.0026 Cls Loss: 0.0014 Tot Loss: 0.0020 Accu :0.9952
# Epoch 35 train Loc Loss: 0.0048 Cls Loss: 0.0027 Tot Loss: 0.0038 Accu :0.9921
# VALIDATION: test Loc Loss: 0.0304 Cls Loss: 0.0288 Tot Loss: 0.0296 Accu :0.5400
# Step 5355/6000
# ----------
# Epoch 36 train Loc Loss: 0.0007 Cls Loss: 0.0006 Tot Loss: 0.0006 Accu :1.0000
# Epoch 36 train Loc Loss: 0.0032 Cls Loss: 0.0017 Tot Loss: 0.0024 Accu :1.0000
# Epoch 36 train Loc Loss: 0.0034 Cls Loss: 0.0015 Tot Loss: 0.0024 Accu :1.0000
# Epoch 39 train Loc Loss: 0.0022 Cls Loss: 0.0016 Tot Loss: 0.0019 Accu :0.9975
# Epoch 39 train Loc Loss: 0.0023 Cls Loss: 0.0013 Tot Loss: 0.0018 Accu :0.9978
# Epoch 39 train Loc Loss: 0.0021 Cls Loss: 0.0011 Tot Loss: 0.0016 Accu :0.9981
# Epoch 39 train Loc Loss: 0.0028 Cls Loss: 0.0016 Tot Loss: 0.0022 Accu :0.9965
# Epoch 39 train Loc Loss: 0.0019 Cls Loss: 0.0010 Tot Loss: 0.0015 Accu :0.9969
# Epoch 39 train Loc Loss: 0.0019 Cls Loss: 0.0017 Tot Loss: 0.0018 Accu :0.9957
# Epoch 39 train Loc Loss: 0.0026 Cls Loss: 0.0013 Tot Loss: 0.0019 Accu :0.9960
# Epoch 39 train Loc Loss: 0.0021 Cls Loss: 0.0013 Tot Loss: 0.0017 Accu :0.9963
# Epoch 39 train Loc Loss: 0.0034 Cls Loss: 0.0017 Tot Loss: 0.0026 Accu :0.9954
# VALIDATION: test Loc Loss: 0.0306 Cls Loss: 0.0283 Tot Loss: 0.0295 Accu :0.5800
# Step 5967/6000
# ----------
# Epoch 40 train Loc Loss: 0.0006 Cls Loss: 0.0004 Tot Loss: 0.0005 Accu :1.0000
# Epoch 40 train Loc Loss: 0.0028 Cls Loss: 0.0014 Tot Loss: 0.0021 Accu :1.0000
# Epoch 40 train Loc Loss: 0.0035 Cls Loss: 0.0015 Tot Loss: 0.0025 Accu :1.0000
# Epoch 40 train Loc Loss: 0.0022 Cls Loss: 0.0012 Tot Loss: 0.0017 Accu :1.0000
# Epoch 40 train Loc Loss: 0.0018 Cls Loss: 0.0010 Tot Loss: 0.0014 Accu :1.0000
# Epoch 40 train Loc Loss: 0.0016 Cls Loss: 0.0012 Tot Loss: 0.0014 Accu :1.0000
# Epoch 40 train Loc Loss: 0.0027 Cls Loss: 0.0011 Tot Loss: 0.0019 Accu :1.0000
# Epoch 40 train Loc Loss: 0.0028 Cls Loss: 0.0018 Tot Loss: 0.0023 Accu :0.9977
# Epoch 40 train Loc Loss: 0.0029 Cls Loss: 0.0012 Tot Loss: 0.0020 Accu :0.9980
# Epoch 40 train Loc Loss: 0.0017 Cls Loss: 0.0015 Tot Loss: 0.0016 Accu :0.9964
# Epoch 40 train Loc Loss: 0.0022 Cls Loss: 0.0016 Tot Loss: 0.0019 Accu :0.9951
# Epoch 40 train Loc Loss: 0.0023 Cls Loss: 0.0016 Tot Loss: 0.0019 Accu :0.9956
# Epoch 40 train Loc Loss: 0.0021 Cls Loss: 0.0013 Tot Loss: 0.0017 Accu :0.9946
# Epoch 40 train Loc Loss: 0.0022 Cls Loss: 0.0013 Tot Loss: 0.0018 Accu :0.9950
# Epoch 40 train Loc Loss: 0.0023 Cls Loss: 0.0016 Tot Loss: 0.0019 Accu :0.9942
# Epoch 40 train Loc Loss: 0.0128 Cls Loss: 0.0061 Tot Loss: 0.0094 Accu :0.9934
# /content/WLASL/code/I3D/checkpoints/nslt_100_006120_0.580000.pt
# VALIDATION: test Loc Loss: 0.0318 Cls Loss: 0.0293 Tot Loss: 0.0306 Accu :0.5800

# %% [markdown]
# ## Testing

# %%
# prompt: download this folder /content/WLASL/code/I3D/checkpoints download

# !zip -r /content/checkpoints.zip /content/WLASL/code/I3D/checkpoints
from google.colab import files
files.download('/content/checkpoints.zip')
# Out:
#   adding: content/WLASL/code/I3D/checkpoints/ (stored 0%)

# %%
# !gdown --id 1jALimVOB69ifYkeT0Pe297S1z4U3jC48
# Out:
# /usr/local/lib/python3.11/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1jALimVOB69ifYkeT0Pe297S1z4U3jC48
# From (redirected): https://drive.google.com/uc?id=1jALimVOB69ifYkeT0Pe297S1z4U3jC48&confirm=t&uuid=fc8130aa-dde1-4239-884d-9e4322b17961
# To: /content/WLASL/code/I3D/archived.zip
# 100% 197M/197M [00:02<00:00, 72.6MB/s]

# %%
# !unzip /content/WLASL/code/I3D/archived.zip
# Out:
# Archive:  /content/WLASL/code/I3D/archived.zip
#    creating: archived/
#    creating: archived/asl100/
#   inflating: archived/asl100/FINAL_nslt_100_iters=896_top1=65.89_top5=84.11_top10=89.92.pt
#   inflating: archived/asl100/FINAL_nslt_100_iters=896_top1=65.89_top5=84.11_top10=89.92.ini
#    creating: archived/asl300/
#   inflating: archived/asl300/FINAL_nslt_300_iters=2997_top1=56.14_top5=79.94_top10=86.98.pt
#   inflating: archived/asl300/FINAL_nslt_300_iters=2997_top1=56.14_top5=79.94_top10=86.98.ini
#    creating: archived/asl1000/
#   inflating: archived/asl1000/FINAL_nslt_1000_iters=5104_top1=47.33_top5=76.44_top10=84.33.pt
#   inflating: archived/asl1000/FINAL_nslt_1000_iters=5104_top1=47.33_top5=76.44_top10=84.33.ini
#    creating: archived/asl2000/
#   inflating: archived/asl2000/FINAL_nslt_2000_iters=5104_top1=32.48_top5=57.31_top10=66.31.pt
#   inflating: archived/asl2000/FINAL_nslt_2000_iters=5104_top1=32.48_top5=57.31_top10=66.31.ini

# %%
# !ls
# Out:
# archived      configfiles  models	   test_i3d.py
# archived.zip  configs.py   preprocess	   train_i3d.py
# checkpoints   datasets	   pytorch_i3d.py  videotransforms.py

# %%
# %%writefile test_i3d.py
import json
import os
import os.path

import cv2
import numpy as np
import torch
import torch.utils.data as data_utl


def video_to_tensor(pic):
    """Convert a ``numpy.ndarray`` to tensor.
    Converts a numpy.ndarray (T x H x W x C)
    to a torch.FloatTensor of shape (C x T x H x W)

    Args:
         pic (numpy.ndarray): Video to be converted to tensor.
    Returns:
         Tensor: Converted video.
    """
    return torch.from_numpy(pic.transpose([3, 0, 1, 2]))


def load_rgb_frames_from_video(vid_root, vid, start, num):
    video_path = os.path.join(vid_root, vid + '.mp4')

    vidcap = cv2.VideoCapture(video_path)
    # vidcap = cv2.VideoCapture('/home/dxli/Desktop/dm_256.mp4')

    frames = []

    vidcap.set(cv2.CAP_PROP_POS_FRAMES, start)
    for offset in range(num):
        success, img = vidcap.read()

        w, h, c = img.shape
        if w < 226 or h < 226:
            d = 226. - min(w, h)
            sc = 1 + d / min(w, h)
            img = cv2.resize(img, dsize=(0, 0), fx=sc, fy=sc)
        img = (img / 255.) * 2 - 1

        frames.append(img)

    return np.asarray(frames, dtype=np.float32)


def load_rgb_frames(image_dir, vid, start, end):
    frames = []
    for i in range(start, end):
        try:
            img = cv2.imread(os.path.join(image_dir, vid, "image_" + str(i).zfill(5) + '.jpg'))[:, :, [2, 1, 0]]
        except:
            print(os.path.join(image_dir, vid, str(i).zfill(6) + '.jpg'))
        w, h, c = img.shape
        if w < 226 or h < 226:
            d = 226. - min(w, h)
            sc = 1 + d / min(w, h)
            img = cv2.resize(img, dsize=(0, 0), fx=sc, fy=sc)
        img = (img / 255.) * 2 - 1
        frames.append(img)
    return np.asarray(frames, dtype=np.float32)


def load_flow_frames(image_dir, vid, start, num):
    frames = []
    for i in range(start, start + num):
        imgx = cv2.imread(os.path.join(image_dir, vid, vid + '-' + str(i).zfill(6) + 'x.jpg'), cv2.IMREAD_GRAYSCALE)
        imgy = cv2.imread(os.path.join(image_dir, vid, vid + '-' + str(i).zfill(6) + 'y.jpg'), cv2.IMREAD_GRAYSCALE)

        w, h = imgx.shape
        if w < 224 or h < 224:
            d = 224. - min(w, h)
            sc = 1 + d / min(w, h)
            imgx = cv2.resize(imgx, dsize=(0, 0), fx=sc, fy=sc)
            imgy = cv2.resize(imgy, dsize=(0, 0), fx=sc, fy=sc)

        imgx = (imgx / 255.) * 2 - 1
        imgy = (imgy / 255.) * 2 - 1
        img = np.asarray([imgx, imgy]).transpose([1, 2, 0])
        frames.append(img)
    return np.asarray(frames, dtype=np.float32)


def make_dataset(split_file, split, root, mode, num_classes):
    dataset = []
    with open(split_file, 'r') as f:
        data = json.load(f)

    i = 0
    for vid in data.keys():
        if data[vid]['subset'] != "test":
            continue
        video_path = os.path.join(root, vid + '.mp4')
        if not os.path.exists(video_path):
            continue
        # num_frames = data[vid]['action'][2] - data[vid]['action'][1]
        num_frames = int(cv2.VideoCapture(video_path).get(cv2.CAP_PROP_FRAME_COUNT))
        if mode == 'flow':
            num_frames = num_frames // 2

        label = np.zeros((num_classes, num_frames), np.float32)

        # dataset.append((vid, data[vid]['action'][0], data[vid]['action'][1], data[vid]['action'][2], "{}".format(vid)))
        dataset.append((vid, data[vid]['action'][0], 0, num_frames, "{}".format(vid)))
        # dataset.append((vid, label, 0, data[vid]['action'][2] - data[vid]['action'][1], "{}".format(vid)))
        i += 1
    print(len(dataset))
    return dataset


def get_num_class(split_file):
    classes = set()

    content = json.load(open(split_file))

    for vid in content.keys():
        class_id = content[vid]['action'][0]
        classes.add(class_id)

    return len(classes)


class NSLT(data_utl.Dataset):

    def __init__(self, split_file, split, root, mode, transforms=None):
        self.num_classes = get_num_class(split_file)

        self.data = make_dataset(split_file, split, root, mode, self.num_classes)
        self.split_file = split_file
        self.transforms = transforms
        self.mode = mode
        self.root = root

    def __getitem__(self, index):
        """
        Args:
            index (int): Index

        Returns:
            tuple: (image, target) where target is class_index of the target class.
        """
        vid, label, start_f, start_e, output_name = self.data[index]

        if self.mode == 'rgb':
            # imgs = load_rgb_frames(self.root, vid, start_f, start_e)
            # imgs = load_rgb_frames(self.root, vid, start_f, start_e)
            imgs = load_rgb_frames_from_video(self.root, vid, start_f, start_e)
        else:
            imgs = load_flow_frames(self.root, vid, start_f, start_e)
        # label = label[:, start_f:start_e]

        imgs = self.transforms(imgs)
        ret_img = video_to_tensor(imgs)
        return ret_img, label, vid

    def __len__(self):
        return len(self.data)

#---------------------------------------
import math
import os
import argparse

import matplotlib.pyplot as plt

import torch
import torch.nn as nn

from torchvision import transforms
import videotransforms

import numpy as np

import torch.nn.functional as F
from pytorch_i3d import InceptionI3d

# from nslt_dataset_all import NSLT as Dataset
#from datasets.nslt_dataset_all import NSLT as Dataset
import cv2


os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = '0'
parser = argparse.ArgumentParser()
parser.add_argument('-mode', type=str, help='rgb or flow')
parser.add_argument('-save_model', type=str)
parser.add_argument('-root', type=str)

args = parser.parse_args()


def load_rgb_frames_from_video(video_path, start=0, num=-1):
    vidcap = cv2.VideoCapture(video_path)
    # vidcap = cv2.VideoCapture('/home/dxli/Desktop/dm_256.mp4')

    frames = []

    vidcap.set(cv2.CAP_PROP_POS_FRAMES, start)
    if num == -1:
        num = int(vidcap.get(cv2.CAP_PROP_FRAME_COUNT))

    for offset in range(num):
        success, img = vidcap.read()

        w, h, c = img.shape
        sc = 224 / w
        img = cv2.resize(img, dsize=(0, 0), fx=sc, fy=sc)

        img = (img / 255.) * 2 - 1

        frames.append(img)

    return torch.Tensor(np.asarray(frames, dtype=np.float32))


def run(init_lr=0.1,
        max_steps=64e3,
        mode='rgb',
        root='/ssd/Charades_v1_rgb',
        train_split='charades/charades.json',
        batch_size=3 * 15,
        save_model='',
        weights=None):
    # setup dataset
    test_transforms = transforms.Compose([videotransforms.CenterCrop(224)])

    val_dataset = NSLT(train_split, 'test', root, mode, test_transforms)
    val_dataloader = torch.utils.data.DataLoader(val_dataset, batch_size=1,
                                                 shuffle=False, num_workers=2,
                                                 pin_memory=False)

    dataloaders = {'test': val_dataloader}
    datasets = {'test': val_dataset}

    # setup the model
    if mode == 'flow':
        i3d = InceptionI3d(400, in_channels=2)
        i3d.load_state_dict(torch.load('/content/WLASL/weights/flow_imagenet.pt'))
    else:
        i3d = InceptionI3d(400, in_channels=3)
        i3d.load_state_dict(torch.load('/content/WLASL/weights/rgb_imagenet.pt'))
    i3d.replace_logits(num_classes)
    i3d.load_state_dict(torch.load(weights))  # nslt_2000_000700.pt nslt_1000_010800 nslt_300_005100.pt(best_results)  nslt_300_005500.pt(results_reported) nslt_2000_011400
    i3d.cuda()
    i3d = nn.DataParallel(i3d)
    i3d.eval()

    correct = 0
    correct_5 = 0
    correct_10 = 0

    top1_fp = np.zeros(num_classes, dtype=np.int32)
    top1_tp = np.zeros(num_classes, dtype=np.int32)

    top5_fp = np.zeros(num_classes, dtype=np.int32)
    top5_tp = np.zeros(num_classes, dtype=np.int32)

    top10_fp = np.zeros(num_classes, dtype=np.int32)
    top10_tp = np.zeros(num_classes, dtype=np.int32)

    for data in dataloaders["test"]:
        inputs, labels, video_id = data  # inputs: b, c, t, h, w

        per_frame_logits = i3d(inputs)

        predictions = torch.max(per_frame_logits, dim=2)[0]
        out_labels = np.argsort(predictions.cpu().detach().numpy()[0])
        out_probs = np.sort(predictions.cpu().detach().numpy()[0])

        if labels[0].item() in out_labels[-5:]:
            correct_5 += 1
            top5_tp[labels[0].item()] += 1
        else:
            top5_fp[labels[0].item()] += 1
        if labels[0].item() in out_labels[-10:]:
            correct_10 += 1
            top10_tp[labels[0].item()] += 1
        else:
            top10_fp[labels[0].item()] += 1
        if torch.argmax(predictions[0]).item() == labels[0].item():
            correct += 1
            top1_tp[labels[0].item()] += 1
        else:
            top1_fp[labels[0].item()] += 1
        print(video_id, float(correct) / len(dataloaders["test"]), float(correct_5) / len(dataloaders["test"]),
              float(correct_10) / len(dataloaders["test"]))

        # per-class accuracy
    top1_per_class = np.mean(top1_tp / (top1_tp + top1_fp))
    top5_per_class = np.mean(top5_tp / (top5_tp + top5_fp))
    top10_per_class = np.mean(top10_tp / (top10_tp + top10_fp))
    print('top-k average per class acc: {}, {}, {}'.format(top1_per_class, top5_per_class, top10_per_class))


def ensemble(mode, root, train_split, weights, num_classes):
    # setup dataset
    test_transforms = transforms.Compose([videotransforms.CenterCrop(224)])
    # test_transforms = transforms.Compose([])

    val_dataset = Dataset(train_split, 'test', root, mode, test_transforms)
    val_dataloader = torch.utils.data.DataLoader(val_dataset, batch_size=1,
                                                 shuffle=False, num_workers=2,
                                                 pin_memory=False)

    dataloaders = {'test': val_dataloader}
    datasets = {'test': val_dataset}

    # setup the model
    if mode == 'flow':
        i3d = InceptionI3d(400, in_channels=2)
        i3d.load_state_dict(torch.load('/content/WLASL/weights/flow_imagenet.pt'))
    else:
        i3d = InceptionI3d(400, in_channels=3)
        i3d.load_state_dict(torch.load('/content/WLASL/weights/rgb_imagenet.pt'))
    i3d.replace_logits(num_classes)
    i3d.load_state_dict(torch.load(weights))  # nslt_2000_000700.pt nslt_1000_010800 nslt_300_005100.pt(best_results)  nslt_300_005500.pt(results_reported) nslt_2000_011400
    i3d.cuda()
    i3d = nn.DataParallel(i3d)
    i3d.eval()

    correct = 0
    correct_5 = 0
    correct_10 = 0
    # confusion_matrix = np.zeros((num_classes,num_classes), dtype=np.int)

    top1_fp = np.zeros(num_classes, dtype=np.int)
    top1_tp = np.zeros(num_classes, dtype=np.int)

    top5_fp = np.zeros(num_classes, dtype=np.int)
    top5_tp = np.zeros(num_classes, dtype=np.int)

    top10_fp = np.zeros(num_classes, dtype=np.int)
    top10_tp = np.zeros(num_classes, dtype=np.int)

    for data in dataloaders["test"]:
        inputs, labels, video_id = data  # inputs: b, c, t, h, w

        t = inputs.size(2)
        num = 64
        if t > num:
            num_segments = math.floor(t / num)

            segments = []
            for k in range(num_segments):
                segments.append(inputs[:, :, k*num: (k+1)*num, :, :])

            segments = torch.cat(segments, dim=0)
            per_frame_logits = i3d(segments)

            predictions = torch.mean(per_frame_logits, dim=2)

            if predictions.shape[0] > 1:
                predictions = torch.mean(predictions, dim=0)

        else:
            per_frame_logits = i3d(inputs)
            predictions = torch.mean(per_frame_logits, dim=2)[0]

        out_labels = np.argsort(predictions.cpu().detach().numpy())

        if labels[0].item() in out_labels[-5:]:
            correct_5 += 1
            top5_tp[labels[0].item()] += 1
        else:
            top5_fp[labels[0].item()] += 1
        if labels[0].item() in out_labels[-10:]:
            correct_10 += 1
            top10_tp[labels[0].item()] += 1
        else:
            top10_fp[labels[0].item()] += 1
        if torch.argmax(predictions).item() == labels[0].item():
            correct += 1
            top1_tp[labels[0].item()] += 1
        else:
            top1_fp[labels[0].item()] += 1
        print(video_id, float(correct) / len(dataloaders["test"]), float(correct_5) / len(dataloaders["test"]),
              float(correct_10) / len(dataloaders["test"]))

    top1_per_class = np.mean(top1_tp / (top1_tp + top1_fp))
    top5_per_class = np.mean(top5_tp / (top5_tp + top5_fp))
    top10_per_class = np.mean(top10_tp / (top10_tp + top10_fp))
    print('top-k average per class acc: {}, {}, {}'.format(top1_per_class, top5_per_class, top10_per_class))


def run_on_tensor(weights, ip_tensor, num_classes):
    i3d = InceptionI3d(400, in_channels=3)
    # i3d.load_state_dict(torch.load('models/rgb_imagenet.pt'))

    i3d.replace_logits(num_classes)
    i3d.load_state_dict(torch.load(weights))  # nslt_2000_000700.pt nslt_1000_010800 nslt_300_005100.pt(best_results)  nslt_300_005500.pt(results_reported) nslt_2000_011400
    i3d.cuda()
    i3d = nn.DataParallel(i3d)
    i3d.eval()

    t = ip_tensor.shape[2]
    ip_tensor.cuda()
    per_frame_logits = i3d(ip_tensor)

    predictions = F.upsample(per_frame_logits, t, mode='linear')

    predictions = predictions.transpose(2, 1)
    out_labels = np.argsort(predictions.cpu().detach().numpy()[0])

    arr = predictions.cpu().detach().numpy()[0,:,0].T

    plt.plot(range(len(arr)), F.softmax(torch.from_numpy(arr), dim=0).numpy())
    plt.show()

    return out_labels


def get_slide_windows(frames, window_size, stride=1):
    indices = torch.arange(0, frames.shape[0])
    window_indices = indices.unfold(0, window_size, stride)

    return frames[window_indices, :, :, :].transpose(1, 2)


if __name__ == '__main__':
    # ================== test i3d on a dataset ==============
    # need to add argparse
    mode = 'rgb'
    num_classes = 100
    save_model = './checkpoints/'

    root = '../../data/WLASL2000'

    train_split = '/content/WLASL/code/I3D/preprocess/nslt_{}.json'.format(num_classes)
    weights = '/content/WLASL/code/I3D/archived/asl100/FINAL_nslt_100_iters=896_top1=65.89_top5=84.11_top10=89.92.pt'

    run(mode=mode, root=root, save_model=save_model, train_split=train_split, weights=weights)
# Out:
# Overwriting test_i3d.py

# %%
# !python test_i3d.py
